# %% [markdown]
# <a href="https://colab.research.google.com/github/vivomouallem12-oss/cloud-tirgul/blob/main/MyFirstColabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Wed Mar 18 09:00:00 2026

# %%
time.sleep(5)
print (time.ctime())
# Out:
# Wed Mar 18 09:00:05 2026
